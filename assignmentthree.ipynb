# %%
num1 = float(input("Enter a Number: "))
num2 = float(input("Enter a Number: "))
num3 = float(input("Enter a Number: "))

print("The Largest Number is", max(num1, num2, num3))
# Out:
# Enter a Number:  27
# Enter a Number:  24
# Enter a Number:  17
# The Largest Number is 27.0
