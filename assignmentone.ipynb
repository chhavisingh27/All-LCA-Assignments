# %%
Student_Dictionary={"name": "Chhavi",
    "age": 19,
    "city": "pune"}
print("Student Dictionary:"+str(Student_Dictionary))
# Out:
# Student Dictionary:{'name': 'Chhavi', 'age': 19, 'city': 'pune'}

# %%
Student_List=["Atharva","Soham","sruti","Hardik","krishna"]
print("Student List:"+str(Student_List))
# Out:
# Student List:['Atharva', 'Soham', 'sruti', 'Hardik', 'krishna']

# %%
Student_Tuple=("Dhruv","Darshan","Shreya","Maddy","Raj")
print("Student Tuple:"+str(Student_Tuple))
# Out:
# Student Tuple:('Dhruv', 'Darshan', 'Shreya', 'Maddy', 'Raj')

# %%
Student_Dictionary={"name": "krishna",
    "age": 18,
    "city": "pune"}

Student_Dictionary["College"]="MIT WPU"
print("Student Dictionary:"+str(Student_Dictionary))
# Out:
# Student Dictionary:{'name': 'krishna', 'age': 18, 'city': 'pune', 'College': 'MIT WPU'}

# %%
Student_Dictionary={"name": "Dwij",
    "age": 18,
    "city": "pune"}
Student_Dictionary.pop("age")
print(Student_Dictionary)
# Out:
# {'name': 'Dwij', 'city': 'pune'}

# %%
Student_Dictionary={"name": "Rudra",
    "age": 18,
    "city": "pune"}
Student_Dictionary.update({"age":19, "city": "Mumbai"})
print(Student_Dictionary)
# Out:
# {'name': 'Rudra', 'age': 19, 'city': 'Mumbai'}
